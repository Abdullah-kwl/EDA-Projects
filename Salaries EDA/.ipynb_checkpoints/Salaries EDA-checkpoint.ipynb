# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('salaries_data.csv')
df
# Out:
# c:\users\rehman baba\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# ...

# %% [markdown]
# ### 1.  Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (148654, 13)

# %% [markdown]
# ### 4.  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# ### 5. Check Null Values In The Dataset

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# ### 6. Drop ID, Notes, Agency, and Status Columns

# %%
print("No of Columns =",len(df.columns))
df.columns
# Out:
# No of Columns = 13
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.drop(columns=['Id','Notes', 'Agency', 'Status'],inplace=True)

# %%
print("No of Columns =",len(df.columns))
df.columns
# Out:
# No of Columns = 9
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %% [markdown]
# ### 7. Get Overall Statistics About The Dataframe

# %%
df.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %% [markdown]
# ### 8. Find Occurrence of The Employee Names  (Top 5)

# %%
df['EmployeeName'].value_counts()[:5]
# Out:
# Kevin Lee       13
# Steven Lee      11
# Richard Lee     11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# ### 9. Find The Number of Unique Job Titles (top 10)

# %%
df['JobTitle'].value_counts()[:10]
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### 10.Total Number of Job Titles Contain Captain

# %%
df['JobTitle'].str.contains('Captain').sum()
# Out:
# 411

# %%
df[df['JobTitle'].str.contains('Captain')]
# Out:
#               EmployeeName                   JobTitle    BasePay OvertimePay  \
# 36167        John Goldberg                  Captain 3   104404.0         0.0
# 36180     Michael Rolovich  Captain, Fire Suppression  145659.03   125868.06
# 36184        Darryl Hunter  Captain, Fire Suppression  145659.03   115673.73
# 36186       Michael Delane  Captain, Fire Suppression  147069.71   113372.94
# 36189       Philip Stevens  Captain, Fire Suppression   124573.5    53895.92
# ...                    ...                        ...        ...         ...
# 116604   Gregory L Stewart  Captain, Fire Suppression   73355.21    18517.18
# 120867     Michael J Moran                  Captain 3     7660.0     1496.09
# 122361  Michael V Rolovich  Captain, Fire Suppression        0.0         0.0
# 126588    Stephen M Tittel                  Captain 3   68491.89         0.0
# 132232     Jeanne M Seyler  Captain, Fire Suppression   61039.43     2285.30
#
# ...

# %%
df[df['JobTitle'].str.contains('Captain')]['JobTitle']
# Out:
# 36167                     Captain 3
# 36180     Captain, Fire Suppression
# 36184     Captain, Fire Suppression
# 36186     Captain, Fire Suppression
# 36189     Captain, Fire Suppression
#                     ...
# 116604    Captain, Fire Suppression
# 120867                    Captain 3
# 122361    Captain, Fire Suppression
# 126588                    Captain 3
# 132232    Captain, Fire Suppression
# Name: JobTitle, Length: 411, dtype: object

# %% [markdown]
# ### 11. Display All the Employee Names From Fire Department

# %%
df[df['JobTitle'].str.contains('Fire')]
# Out:
#               EmployeeName                        JobTitle    BasePay  \
# 36159       Gary Altenberg    Lieutenant, Fire Suppression  128808.87
# 36162   Joanne Hayes-White          Chief, Fire Department  296943.01
# 36163    Frederick Binkley       EMT/Paramedic/Firefighter  126863.19
# 36168       David Franklin    Asst Chf of Dept (Fire Dept)  204032.52
# 36169         Brendan Ward  Battlion Chief, Fire Suppressi  174822.47
# ...                    ...                             ...        ...
# 145956    Kenneth C Farris                     Firefighter       0.00
# 147556       Edward A Dunn                     Firefighter    1063.24
# 148021      Kari A Johnson                     Firefighter     688.71
# 148209        Sheryl K Lee                     Firefighter     459.14
# 148554     Lawrence F Gatt           Fire Alarm Dispatcher      73.33
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# ...

# %%
df[df['JobTitle'].str.contains('Fire')]['EmployeeName']
# Out:
# 36159         Gary Altenberg
# 36162     Joanne Hayes-White
# 36163      Frederick Binkley
# 36168         David Franklin
# 36169           Brendan Ward
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 4420, dtype: object

# %% [markdown]
# ### 12. Find Minimum, Maximum, and Average BasePay

# %%
df['BasePay']=df['BasePay'].replace({'Not Provided' : 0}).astype(np.float64)

# %%
df['BasePay'].describe()
# Out:
# count    148049.000000
# mean      66323.656854
# std       42765.447379
# min        -166.010000
# 25%       33583.520000
# 50%       65006.930000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %% [markdown]
# ### 13. Replace 'Not Provided' in EmployeeName' Column to NaN
#
# we already replace that to 0

# %% [markdown]
# ### 14. Drop The Rows Having 5 Missing Values
# i already make changes in data so we cannot answer this question

# %%
df.isnull().sum(axis=0)
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
df[df.isnull().sum(axis=1)==1]
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 110526     Arthur L Curry                         PS Aide Health Services
# 110527      Nereida  Vega                                    Senior Clerk
# 110528   Timothy E Gibson                                Police Officer 3
# 110529     Mark E Laherty                                Police Officer 3
# 110530      David P Kucia                                Police Officer 3
#
#           BasePay OvertimePay   OtherPay Benefits   TotalPay  \
# ...

# %% [markdown]
# ### 15. Find Job Title of ALBERT PARDINI

# %%
df[df['EmployeeName']=='Albert Pardini']
# Out:
#          EmployeeName   JobTitle    BasePay OvertimePay  OtherPay  Benefits  \
# 36519  Albert Pardini  Captain 3  196265.04         0.0  11404.04  46326.21
#
#         TotalPay  TotalPayBenefits  Year
# 36519  207669.08         253995.29  2012

# %%
df[df['EmployeeName']=='Albert Pardini'].JobTitle
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: object

# %% [markdown]
# ### 16. How Much ALBERT PARDINI Make (Include Benefits)?

# %%
196265.04+0.0+11404.04+46326.21+207669.08+253995.29
# Out:
# 715659.66

# %%
df[df['EmployeeName']=='Albert Pardini'].iloc[[0],[2,3,4,5,6,7]].sum(axis=1)
# Out:
# 36519    715659.66
# dtype: float64

# %% [markdown]
# ### 17.Display Name of The Person Having The Highest BasePay

# %%
df[df['BasePay']==df['BasePay'].max()]
# Out:
#          EmployeeName         JobTitle    BasePay OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01         0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year
# 72925  86533.21  339282.07         425815.28  2013

# %% [markdown]
# ### 18.Find Average BasePay of All Employee Per Year

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66557.437750
# Name: BasePay, dtype: float64

# %% [markdown]
# ### 19. Find Average BasePay of All Employee Per JobTitle

# %%
g=df.groupby('JobTitle')
g['BasePay'].mean().sort_values(ascending=False)[:10]
# Out:
# JobTitle
# Chief of Police                           309767.683333
# Chief, Fire Department                    304232.340000
# Gen Mgr, Public Trnsp Dept                297769.413333
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)    285262.000000
# Dep Dir for Investments, Ret              276153.765000
# Mayor                                     275852.530000
# Adm, SFGH Medical Center                  265218.780000
# EXECUTIVE CONTRACT EMPLOYEE               264452.520000
# Controller                                263588.753333
# Dept Head V                               259590.712222
# Name: BasePay, dtype: float64

# %% [markdown]
# ### 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
g.get_group('ACCOUNTANT')['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# ### 21. Find Top 5 Most Common Jobs

# %%
df['JobTitle'].value_counts()[:5]
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
